# %% [markdown]
# # **#v0.1.0**

# %%
import oikos as ok

# %%
# Prueba con una fórmula simple primero
demanda = ok.Demand(r"Q = 10 + P")
oferta = ok.Supply(r"Q = -10 + 2P")

equilibrio = ok.equilibrium(oferta, demanda)
show(demanda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 6
#       3 oferta = ok.Supply(r"Q = -10 + 2P")
#       5 equilibrio = ok.equilibrium(oferta, demanda)
# ----> 6 show(demanda)
#
# NameError: name 'show' is not defined

# %%
demanda = ok.Demand(r"Q = 120 - P")
oferta = ok.Supply(r"Q = 2P")

equilibrio = ok.equilibrium(oferta, demanda)

# %%
demanda = ok.Demand(r"P = 120 - Q")
oferta = ok.Supply(r"P = \frac{1}{2Q}")

equilibrio = ok.equilibrium(oferta, demanda)
print(equilibrio)
